# %% [markdown]
# # Causal Forest trên Kaggle — notebook đã chạy, có output
#
# > ## Trạng thái: đã chạy xong trên Kaggle. Output trong file này là output thật của lần chạy đó.
# >
# > Đây là notebook Kaggle trả về sau `Save Version → Save & Run All`, không phải bản công
# > thức chưa chạy. Metadata `papermill` ghi lại lần chạy:
# >
# > | | |
# > |---|---|
# > | Thời điểm | `2026-08-05T16:17:40Z` → `2026-08-05T17:10:53Z` |
# > | Tổng thời gian | 3.192,7 giây (53,2 phút) |
# > | Exception | không có (`exception: null`) |
# > | Session | 4 logical CPU, 2 physical, 31,35 GB RAM |
# > | Dữ liệu | `criteo-uplift-v2.1.csv`, 3.248.115.221 byte, checksum khớp |
# >
# > Chạy trên máy chủ Kaggle vì laptop 15,19 GB không đủ RAM cho stage 50%.
# >
# > **Ba stage đều `passed`** — số dưới đây đọc thẳng từ output các cell trong file này và
# > khớp với `gate_manifest.json` đã tải về repo:
# >
# > | Stage | Peak RSS | RAM fraction | Wall time | Manifest trong repo |
# > |---|---:|---:|---:|---|
# > | 20% | 5,52 GB | 0,176 | 9,6 phút | `output/causal_forest/preflight_0p2/gate_manifest.json` |
# > | 30% | 7,88 GB | 0,251 | 15,1 phút | `output/causal_forest/preflight_0p3/gate_manifest.json` |
# > | 50% | 12,73 GB | 0,406 | 26,5 phút | `output/causal_forest/preflight_0p5/gate_manifest.json` |
# >
# > **Gate không chấm chất lượng model.** `"quality_not_assessed": true` nằm ngay trong cả
# > ba manifest: gate chỉ kiểm checksum dữ liệu, thứ tự stage, exit code, peak RSS, tính hữu
# > hạn của score và số dòng score khớp holdout. Chấm điểm làm ở local bằng
# > `scripts/evaluate_causal_forest.py`.
# >
# > **Kết quả sau khi chấm điểm** — holdout 2.096.940 dòng, trùng khít final test Sprint 1:
# > Causal Forest `policy_area_dr = 0,0010057` so với Response `0,0010052`, chênh lệch ở chữ
# > số thứ bảy; Qini thì thấp hơn (`0,1747` so với `0,1879`). Paired 95% CI chứa 0 trên **cả
# > hai** metric, nên đây là **hoà**, không phải thắng. Báo cáo đầy đủ kèm learning curve và
# > năm biểu đồ: **[`report/04_CAUSAL_FOREST.md`](../report/04_CAUSAL_FOREST.md)**.
# >
# > **Phạm vi chứng cứ.** Kết quả này chấm trên holdout Sprint 1 với tín hiệu IPW, còn các
# > challenger Sprint 3 chấm trên confirmation Sprint 2 với tín hiệu DR. Hai bảng **không so
# > trực tiếp với nhau được**, và Causal Forest không thuộc release Sprint 3.
# >
# > Phần phân tích có biểu đồ và suy luận thống kê nằm ở
# > [`02_modeling_and_evaluation.ipynb`](02_modeling_and_evaluation.ipynb).
#
# Notebook này hoàn tất **hạng mục còn thiếu duy nhất** của dự án: chạy `CausalForestDML`
# ở quy mô thật. Laptop 15,19 GB không đủ (ngoại suy 50% cần khoảng 17,5 GB).
#
# ## Ba việc bắt buộc trước khi chạy
#
# 1. **Settings → Accelerator = `None (CPU)`.** GPU không làm forest nhanh hơn:
#    `CausalForestDML` dùng CPU parallelism và system RAM, không dùng CUDA.
# 2. **Settings → Internet = `On`.** Cần cho `pip install` và `git clone`. Đây là lỗi
#    khiến Cell 3 và Cell 4 fail mà thông báo lỗi không nói rõ nguyên nhân.
# 3. **Add Input → attach dataset Criteo v2.1.** Bấm nút `+` bên phải tên dataset trong
#    panel; chỉ tìm thấy dataset trong ô search là **chưa** attach.
#
# ## Dùng Save & Run All, đừng chạy interactive
#
# **`Save Version → Save & Run All (Commit)`.**
#
# Kaggle sẽ chạy nền trên máy chủ của họ và lưu output vĩnh viễn thành một version. Đóng
# trình duyệt, mất mạng, hay session hết giờ đều không ảnh hưởng.
#
# Chạy interactive thì `/kaggle/working` **bị xoá sạch mỗi lần session restart**. Điều này
# đã xảy ra một lần trong dự án: cả ba stage chạy xong, file zip 30,9 MB đã tạo, rồi mất
# toàn bộ vì session restart trước khi kịp tải về.
#
# Notebook này không cần restart kernel giữa chừng (xem Cell 5), nên `Run All` chạy được
# từ đầu tới cuối.
#
# Muốn chạy interactive để theo dõi thì vẫn được, nhưng **tải zip ở Cell 11 xuống ngay khi
# nó vừa tạo xong**, đừng để sang việc khác.
#
# ## Về định dạng dữ liệu
#
# Kaggle **giải nén** file `.csv.gz` khi bạn upload trực tiếp. File mount vào
# `/kaggle/input` vì thế là CSV thô 3.248.115.221 byte, không phải bản nén 311.422.618
# byte. Nội dung hai bản giống nhau bit-for-bit. Cell 2 và gate script chấp nhận cả hai,
# mỗi dạng một checksum riêng, nên không cần upload lại dataset.

# %% [markdown]
# ## Cell 1 — Đọc tài nguyên thật của session
#
# Không giả định Kaggle luôn cấp cùng một cấu hình. Ghi lại `RAM total`: toàn bộ stop rule
# tính theo tỷ lệ trên con số này.
#
# Cell này cũng liệt kê mọi file trong `/kaggle/input`. Đọc kỹ phần đó — nó cho biết tên
# file thật và dung lượng thật, là hai thứ Kaggle hay đổi lúc upload.

# %%
import os, platform, shutil
import psutil

vm = psutil.virtual_memory()
disk = shutil.disk_usage('/kaggle/working')
print(f'python            {platform.python_version()}')
print(f'logical cpus      {os.cpu_count()}')
print(f'physical cpus     {psutil.cpu_count(logical=False)}')
print(f'RAM total         {vm.total / 2**30:.2f} GB')
print(f'RAM available     {vm.available / 2**30:.2f} GB')
print(f'working disk free {disk.free / 2**30:.2f} GB')
print()

found = False
for root, _, files in os.walk('/kaggle/input'):
    for name in files:
        p = os.path.join(root, name)
        print(f'{os.path.getsize(p):>16,} byte  {p}')
        found = True
if not found:
    print('KHONG CO FILE NAO trong /kaggle/input')
    print('-> Add Input o thanh ben phai, bam nut + ben canh ten dataset.')

if vm.total / 2**30 < 20:
    print()
    print('CANH BAO: RAM total duoi 20 GB. KHONG chay stage 50%.')
    print('Ket thuc o learning curve 20-30% va bao cao dung nhu vay.')
# Out:
# python            3.12.13
# logical cpus      4
# physical cpus     2
# RAM total         31.35 GB
# RAM available     30.35 GB
# working disk free 19.50 GB
#
#    3,248,115,221 byte  /kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv

# %% [markdown]
# ## Cell 2 — Xác minh checksum dữ liệu
#
# Mất khoảng một phút với bản nén, hai đến ba phút với bản CSV thô 3,2 GB. Đáng, vì nó
# tránh việc phát hiện sai dataset sau ba tiếng chạy.
#
# Nếu checksum sai thì **đừng sửa hằng số cho khớp**. Assert này tồn tại để bảo đảm bạn
# đang chạy đúng Criteo v2.1 nguyên vẹn; kết quả chỉ so được với bảng release Sprint 1 khi
# dữ liệu đúng đến từng byte.

# %%
import glob, hashlib, os

# Hai dang byte hop le cua cung mot du lieu:
#   csv.gz    311.422.618 byte  - ban tai ve goc
#   csv     3.248.115.221 byte  - ban Kaggle da giai nen khi upload
SHA_GZ  = '2716e1bf0fd157a93b5bf86924d9088419dfbac2022c6cd90030220634f616dc'
SHA_CSV = 'e4d7c710ca1f38e523309d0f8a0745d1b53e7392d51f20d1088b6cfeaef222ef'

# Pattern rong: Kaggle co the cat 'research-' hoac bo duoi '.gz' khi upload.
matches = sorted(glob.glob('/kaggle/input/**/*criteo*uplift*v2.1.csv*', recursive=True))
assert matches, (
    'Khong tim thay file Criteo. Kiem tra hai thu:\n'
    '  1. Da bam nut + de attach dataset chua (Add Input o thanh ben phai)?\n'
    '  2. Ten file trong dataset co chua "criteo" va "uplift" va "v2.1" khong?\n'
    '     Xem lai output Cell 1 de biet ten that.'
)
DATA_PATH = matches[0]
if len(matches) > 1:
    print('CANH BAO: tim thay nhieu file, dung file dau tien.')
    for m in matches:
        print('   ', m)

expected = SHA_GZ if DATA_PATH.endswith('.gz') else SHA_CSV
digest = hashlib.sha256()
with open(DATA_PATH, 'rb') as handle:
    for chunk in iter(lambda: handle.read(8 * 1024 * 1024), b''):
        digest.update(chunk)
actual = digest.hexdigest()

print('path  ', DATA_PATH)
print('size  ', f'{os.path.getsize(DATA_PATH):,} byte')
print('dang  ', 'csv.gz' if DATA_PATH.endswith('.gz') else 'csv (Kaggle da giai nen)')
print('sha256', actual)
assert actual == expected, (
    f'Checksum sai.\n  thuc te : {actual}\n  mong doi: {expected}\n'
    'Du lieu khong phai Criteo v2.1 nguyen ven. Tai lai tu '
    'https://ailab.criteo.com/criteo-uplift-prediction-dataset/ va upload lai.'
)
print()
print('checksum OK')
# Out:
# path   /kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv
# size   3,248,115,221 byte
# dang   csv (Kaggle da giai nen)
# sha256 e4d7c710ca1f38e523309d0f8a0745d1b53e7392d51f20d1088b6cfeaef222ef
#
# checksum OK

# %% [markdown]
# ## Cell 3 — Đưa repository vào session
#
# **Cách A** (mặc định) dùng khi repo đã public trên GitHub — đây là trường hợp hiện tại.
#
# **Cách B** dùng khi repo private hoặc Internet = Off: nén repo bỏ `data/`, `.venv/`,
# `output/`, `.git/`, upload thành Kaggle Dataset, rồi đặt `USE_GITHUB = False` và điền
# `REPO_DATASET` bằng đường dẫn mount thật (xem output Cell 1).

# %%
import os, shutil, subprocess

USE_GITHUB = True
REPO_URL = 'https://github.com/ThanhDatVN/Causal-Uplift-for-Activation-and-Retention.git'
REPO_DATASET = '/kaggle/input/<ten-dataset-repo>'   # chi dung khi USE_GITHUB = False
REPO_DIR = '/kaggle/working/repo'

if not os.path.exists(REPO_DIR):
    if USE_GITHUB:
        subprocess.run(['git', 'clone', '--depth', '1', REPO_URL, REPO_DIR], check=True)
    else:
        assert os.path.isdir(REPO_DATASET), f'Khong thay {REPO_DATASET}'
        shutil.copytree(REPO_DATASET, REPO_DIR, dirs_exist_ok=True)

os.chdir(REPO_DIR)
print('cwd:', os.getcwd())
print(sorted(os.listdir('.')))

for required in ('scripts', 'src', 'configs'):
    assert os.path.isdir(required), f'Thieu thu muc {required} trong repo'
for required in ('scripts/kaggle_causal_forest_gate.py', 'scripts/train_causal_forest.py'):
    assert os.path.isfile(required), f'Thieu file {required}'
print('repo OK')
# Out:
# Cloning into '/kaggle/working/repo'...
# cwd: /kaggle/working/repo
# ['.git', '.gitattributes', '.github', '.gitignore', 'CLAUDE.md', 'README.md', 'benchmarks', 'configs', 'docs', 'notebooks', 'output', 'planning', 'pyproject.toml', 'report', 'requirements.txt', 'scripts', 'src', 'tests', 'webapp']
# repo OK

# %% [markdown]
# ## Cell 4 — Cài dependency có ghim phiên bản
#
# Đây là chỗ hỏng thường gặp nhất. `econml==0.16.0` yêu cầu `scikit-learn>=1.0,<1.7` và
# `shap>=0.38.1,<0.49.0`. Image Kaggle thường có scikit-learn mới hơn giới hạn đó.
#
# Cell in ra `exit code`. Khác `0` thì đọc phần stderr ở trên rồi xử lý trước khi đi tiếp.

# %%
import subprocess, sys

packages = [
    'econml==0.16.0',
    'scikit-learn>=1.4,<1.7',   # rang buoc cung cua econml 0.16
    'shap>=0.38.1,<0.49.0',     # rang buoc cung cua econml 0.16
    'lightgbm>=4.5',
    'psutil',
]
result = subprocess.run(
    [sys.executable, '-m', 'pip', 'install', '-q'] + packages,
    capture_output=True, text=True,
)
print(result.stdout[-2000:])
print(result.stderr[-2000:])
print('exit code:', result.returncode)
assert result.returncode == 0, 'pip install that bai, doc stderr o tren'
print()
print('Cai xong. KHONG can restart kernel - xem Cell 5.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 44.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 10.9 MB/s eta 0:00:00
#
#
# exit code: 0
#
# Cai xong. KHONG can restart kernel - xem Cell 5.

# %% [markdown]
# ## Cell 5 — Vì sao **không** cần restart kernel
#
# Kernel của notebook đã nạp `scikit-learn` bản cũ vào bộ nhớ trước khi Cell 4 hạ phiên
# bản. Thông thường đó là lý do phải restart.
#
# Ở đây không cần, vì **toàn bộ phần huấn luyện chạy trong tiến trình con**:
#
# ```python
# subprocess.run([sys.executable, 'scripts/kaggle_causal_forest_gate.py', ...])
# ```
#
# Tiến trình con là một interpreter mới. Nó import `sklearn` và `econml` từ đĩa, nên tự
# thấy phiên bản Cell 4 vừa cài, không liên quan gì tới những gì kernel đang giữ. Cell 6
# vì thế cũng kiểm tra phiên bản bằng subprocess chứ không import thẳng.
#
# **Hệ quả quan trọng:** notebook chạy được `Run All` từ đầu tới cuối, nên dùng được
# `Save Version → Save & Run All (Commit)`. Đó là cách duy nhất giữ được output.

# %% [markdown]
# ## Cell 6 — Kiểm tra phiên bản trong tiến trình con
#
# Cell này là cổng kiểm tra: nếu nó chạy hết mà không assert nào nổ thì môi trường đã đúng
# và ba stage phía sau chỉ còn là vấn đề thời gian.
#
# Kiểm tra chạy trong subprocess vì đó chính là môi trường mà trainer sẽ chạy — kiểm tra
# đúng thứ mình dùng, không kiểm tra thứ khác.

# %%
import glob, os, subprocess, sys, textwrap

REPO_DIR = '/kaggle/working/repo'
OUTPUT_ROOT = '/kaggle/working/output/causal_forest'
os.chdir(REPO_DIR)

matches = sorted(glob.glob('/kaggle/input/**/*criteo*uplift*v2.1.csv*', recursive=True))
assert matches, 'Khong tim thay du lieu Criteo. Xem lai Cell 1 va Cell 2.'
DATA_PATH = matches[0]

print('cwd      ', os.getcwd())
print('data     ', DATA_PATH)
print('output   ', OUTPUT_ROOT)
print()

check = textwrap.dedent('''
    import inspect
    import numpy, scipy, sklearn, lightgbm, econml, pandas
    for m in (numpy, scipy, sklearn, lightgbm, econml, pandas):
        print(f'{m.__name__:14s} {m.__version__}')
    from packaging.version import Version
    assert Version(sklearn.__version__) < Version('1.7'), (
        f'scikit-learn {sklearn.__version__} qua moi cho econml 0.16')
    assert econml.__version__ == '0.16.0', f'econml {econml.__version__}, can 0.16.0'
    from econml.dml import CausalForestDML
    assert 'inference' in inspect.signature(CausalForestDML.__init__).parameters
    print('OK')
''')
result = subprocess.run([sys.executable, '-c', check], capture_output=True, text=True)
print(result.stdout)
if result.returncode != 0:
    print('STDERR:', result.stderr[-2000:])
assert result.returncode == 0, 'Moi truong subprocess chua dung. Chay lai Cell 4.'

print('moi thu OK, san sang chay stage 20%')
# Out:
# cwd       /kaggle/working/repo
# data      /kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv
# output    /kaggle/working/output/causal_forest
#
# numpy          2.0.2
# scipy          1.16.3
# sklearn        1.6.1
# lightgbm       4.6.0
# econml         0.16.0
# pandas         2.3.3
# OK
#
# moi thu OK, san sang chay stage 20%

# %% [markdown]
# ## Cell 7 — Hàm chạy một stage
#
# `kaggle_causal_forest_gate.py` tự kiểm sáu điều: checksum dữ liệu, không cho nhảy stage,
# exit code của trainer, peak RSS dưới ngưỡng RAM, mọi score hữu hạn, số dòng score khớp
# holdout.
#
# Gate **không** chấm chất lượng model — `"quality_not_assessed": true` nằm ngay trong
# manifest. Chấm điểm làm ở local bằng `scripts/evaluate_causal_forest.py`.

# %%
import json, subprocess, sys


def stage_slug(frac):
    """Khop ham _slug trong kaggle_causal_forest_gate.py: 0.2 -> '0p2'."""
    return str(frac).replace('.', 'p')


def run_stage(frac):
    """Chay mot stage, in tom tat. Tra manifest neu pass, None neu fail."""
    print(f'=== stage {frac:.0%} bat dau ===', flush=True)
    result = subprocess.run(
        [sys.executable, 'scripts/kaggle_causal_forest_gate.py',
         '--data-path', DATA_PATH,
         '--frac', str(frac),
         '--output-root', OUTPUT_ROOT,
         '--max-ram-fraction', '0.75'],
        capture_output=True, text=True,
    )
    print(result.stdout[-3000:])
    if result.returncode != 0:
        print('STDERR:', result.stderr[-3000:])
        print(f'stage {frac:.0%} FAIL, exit code {result.returncode}')
        return None

    path = f'{OUTPUT_ROOT}/preflight_{stage_slug(frac)}/gate_manifest.json'
    with open(path) as handle:
        manifest = json.load(handle)
    runtime = manifest['runtime']
    print()
    print('status               ', manifest['status'])
    print('data form            ', manifest['data'].get('form', 'khong ghi'))
    print(f"peak RSS              {runtime['peak_process_tree_rss_gb']:.2f} GB")
    print(f"peak RAM fraction     {runtime['peak_process_tree_ram_fraction']:.3f}")
    print(f"wall time             {runtime['wall_seconds'] / 60:.1f} phut")
    print('may continue         ', manifest['stop_rule']['may_continue'])
    print()
    for nxt in (0.30, 0.50):
        if nxt > frac:
            rss = runtime['peak_process_tree_rss_gb'] * nxt / frac
            minutes = runtime['wall_seconds'] * nxt / frac / 60
            print(f'du bao {nxt:.0%}: RSS ~ {rss:.2f} GB, time ~ {minutes:.0f} phut')
    return manifest

# %% [markdown]
# ## Cell 8 — Stage 20%
#
# Ước tính 35–60 phút tuỳ CPU của session. Đọc dòng `du bao` ở cuối output: nếu dự báo RSS
# cho stage 50% vượt 75% RAM total thì dừng ở 30% và báo cáo learning curve.

# %%
m20 = run_stage(0.20)
# Out:
# === stage 20% bat dau ===
# [data] /kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv dạng csv, checksum khớp
# {
#   "created_utc": "2026-08-05T16:28:42.669571+00:00",
#   "status": "passed",
#   "scope": "resource_and_artifact_integrity_gate_only",
#   "fraction": 0.2,
#   "profile": "kaggle-safe",
#   "command": [
#     "/usr/bin/python3",
#     "/kaggle/working/repo/scripts/train_causal_forest.py",
#     "--data-path",
#     "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "--frac",
#     "0.2",
#     "--profile",
#     "kaggle-safe",
#     "--output-dir",
#     "/kaggle/working/output/causal_forest/preflight_0p2",
#     "--seed",
#     "42"
#   ],
#   "data": {
#     "path": "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "sha256": "e4d7c710ca1f38e523309d0f8a0745d1b53e7392d51f20d1088b6cfeaef222ef",
#     "form": "csv"
#   },
#   "runtime": {
#     "logical_cpus": 4,
#     "physical_cpus": 2,
#     "system_ram_total_gb": 31.347740173339844,
#     "system_ram_available_start_gb": 30.296844482421875,
#     "peak_process_tree_rss_gb": 5.518215179443359,
#     "peak_process_tree_ram_fraction": 0.17603231202408678,
#     "minimum_system_available_gb": 24.93988800048828,
#     "wall_seconds": 574.9599940776825,
#     "exit_code": 0
#   },
#   "artifact_contract": {
#     "score_path": "/kaggle/working/output/causal_forest/preflight_0p2/cate_causal_forest_kaggle_safe.npy",
#     "holdout_path": "/kaggle/working/output/causal_forest/preflight_0p2/holdout_test_yt.npz",
#     "score_rows": 838776,
#     "all_finite": true,
#     "aligned": true
#   },
#   "stop_rule": {
#     "max_ram_fraction": 0.75,
#     "may_continue": true,
#     "quality_not_assessed": true
#   },
#   "limitations": [
#     "Passing this gate does not show that Causal Forest improves Qini.",
#     "GPU selection does not accelerate EconML CausalForestDML itself.",
#     "Kaggle resources and quota must be read live; they are not guaranteed."
#   ]
# }
# [write] /kaggle/working/output/causal_forest/preflight_0p2/gate_manifest.json
#
#
# status                passed
# data form             csv
# peak RSS              5.52 GB
# peak RAM fraction     0.176
# wall time             9.6 phut
# may continue          True
#
# du bao 30%: RSS ~ 8.28 GB, time ~ 14 phut
# du bao 50%: RSS ~ 13.80 GB, time ~ 24 phut

# %% [markdown]
# ## Cell 9 — Stage 30%
#
# Chỉ chạy khi stage 20% `passed` **và** dự báo RSS còn dưới 75% RAM total.

# %%
assert m20 is not None and m20['status'] == 'passed', 'Stage 20% chua pass'
m30 = run_stage(0.30)
# Out:
# === stage 30% bat dau ===
# [data] /kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv dạng csv, checksum khớp
# {
#   "created_utc": "2026-08-05T16:44:03.005745+00:00",
#   "status": "passed",
#   "scope": "resource_and_artifact_integrity_gate_only",
#   "fraction": 0.3,
#   "profile": "kaggle-safe",
#   "command": [
#     "/usr/bin/python3",
#     "/kaggle/working/repo/scripts/train_causal_forest.py",
#     "--data-path",
#     "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "--frac",
#     "0.3",
#     "--profile",
#     "kaggle-safe",
#     "--output-dir",
#     "/kaggle/working/output/causal_forest/preflight_0p3",
#     "--seed",
#     "42"
#   ],
#   "data": {
#     "path": "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "sha256": "e4d7c710ca1f38e523309d0f8a0745d1b53e7392d51f20d1088b6cfeaef222ef",
#     "form": "csv"
#   },
#   "runtime": {
#     "logical_cpus": 4,
#     "physical_cpus": 2,
#     "system_ram_total_gb": 31.347740173339844,
#     "system_ram_available_start_gb": 30.270153045654297,
#     "peak_process_tree_rss_gb": 7.879417419433594,
#     "peak_process_tree_ram_fraction": 0.25135519740382317,
#     "minimum_system_available_gb": 22.582427978515625,
#     "wall_seconds": 905.8458428382874,
#     "exit_code": 0
#   },
#   "artifact_contract": {
#     "score_path": "/kaggle/working/output/causal_forest/preflight_0p3/cate_causal_forest_kaggle_safe.npy",
#     "holdout_path": "/kaggle/working/output/causal_forest/preflight_0p3/holdout_test_yt.npz",
#     "score_rows": 1258164,
#     "all_finite": true,
#     "aligned": true
#   },
#   "stop_rule": {
#     "max_ram_fraction": 0.75,
#     "may_continue": true,
#     "quality_not_assessed": true
#   },
#   "limitations": [
#     "Passing this gate does not show that Causal Forest improves Qini.",
#     "GPU selection does not accelerate EconML CausalForestDML itself.",
#     "Kaggle resources and quota must be read live; they are not guaranteed."
#   ]
# }
# [write] /kaggle/working/output/causal_forest/preflight_0p3/gate_manifest.json
#
#
# status                passed
# data form             csv
# peak RSS              7.88 GB
# peak RAM fraction     0.251
# wall time             15.1 phut
# may continue          True
#
# du bao 50%: RSS ~ 13.13 GB, time ~ 25 phut

# %% [markdown]
# ## Cell 10 — Stage 50%
#
# Đây là stage **duy nhất** so được trực tiếp với bảng release Sprint 1: ở
# `frac=0.50, test_size=0.30, seed=42`, holdout trùng khít final test Sprint 1
# (2.096.940 dòng, `Y` và `T` giống hệt từng phần tử — đã kiểm chứng).
#
# Đo thực tế ở stage 20%: 637 giây trên session 4 logical CPU, 31,35 GB RAM, peak RSS
# 5,50 GB. Ngoại suy tuyến tính cho 50% là khoảng 27 phút, nhưng thời gian fit forest scale
# gần `n log n` nên thực tế nhiều khả năng 30–40 phút. Cả ba stage dưới một tiếng.
#
# Nếu session này nhỏ hơn và thời gian còn lại không đủ, **dừng ở đây** và báo cáo learning
# curve 20–30%. Đó là kết quả hợp lệ, không phải thất bại.

# %%
assert m30 is not None and m30['status'] == 'passed', 'Stage 30% chua pass'
m50 = run_stage(0.50)
# Out:
# === stage 50% bat dau ===
# [data] /kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv dạng csv, checksum khớp
# {
#   "created_utc": "2026-08-05T17:10:49.285757+00:00",
#   "status": "passed",
#   "scope": "resource_and_artifact_integrity_gate_only",
#   "fraction": 0.5,
#   "profile": "kaggle-safe",
#   "command": [
#     "/usr/bin/python3",
#     "/kaggle/working/repo/scripts/train_causal_forest.py",
#     "--data-path",
#     "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "--frac",
#     "0.5",
#     "--profile",
#     "kaggle-safe",
#     "--output-dir",
#     "/kaggle/working/output/causal_forest/preflight_0p5",
#     "--seed",
#     "42"
#   ],
#   "data": {
#     "path": "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "sha256": "e4d7c710ca1f38e523309d0f8a0745d1b53e7392d51f20d1088b6cfeaef222ef",
#     "form": "csv"
#   },
#   "runtime": {
#     "logical_cpus": 4,
#     "physical_cpus": 2,
#     "system_ram_total_gb": 31.347740173339844,
#     "system_ram_available_start_gb": 30.302330017089844,
#     "peak_process_tree_rss_gb": 12.72928237915039,
#     "peak_process_tree_ram_fraction": 0.4060669862887341,
#     "minimum_system_available_gb": 4.989997863769531,
#     "wall_seconds": 1591.6245481967926,
#     "exit_code": 0
#   },
#   "artifact_contract": {
#     "score_path": "/kaggle/working/output/causal_forest/preflight_0p5/cate_causal_forest_kaggle_safe.npy",
#     "holdout_path": "/kaggle/working/output/causal_forest/preflight_0p5/holdout_test_yt.npz",
#     "score_rows": 2096940,
#     "all_finite": true,
#     "aligned": true
#   },
#   "stop_rule": {
#     "max_ram_fraction": 0.75,
#     "may_continue": false,
#     "quality_not_assessed": true
#   },
#   "limitations": [
#     "Passing this gate does not show that Causal Forest improves Qini.",
#     "GPU selection does not accelerate EconML CausalForestDML itself.",
#     "Kaggle resources and quota must be read live; they are not guaranteed."
#   ]
# }
# [write] /kaggle/working/output/causal_forest/preflight_0p5/gate_manifest.json
#
#
# status                passed
# data form             csv
# peak RSS              12.73 GB
# peak RAM fraction     0.406
# wall time             26.5 phut
# may continue          False

# %% [markdown]
# ## Cell 11 — Đóng gói output để tải về
#
# Tải **cả file zip**, không chỉ chép một con số. Toàn bộ manifest, log và score phải về
# repo để audit lại được.
#
# Cell in kèm nội dung ba `gate_manifest.json` để cần gấp thì chép thẳng từ output, không
# phải chờ tải file.
#
# **Chạy qua Save & Run All:** zip nằm ở tab `Output` của version vừa tạo, tải lúc nào
# cũng được.
#
# **Chạy interactive:** dùng link `FileLink` cell này in ra và tải **ngay lập tức**.
# `/kaggle/working` bị xoá sạch khi session restart.

# %%
import json, os, pathlib, shutil

archive = shutil.make_archive('/kaggle/working/causal_forest_output', 'zip', OUTPUT_ROOT)
print(f'{archive}  {os.path.getsize(archive) / 2**20:.1f} MB')
print()
for root, _, files in os.walk(OUTPUT_ROOT):
    for name in sorted(files):
        p = os.path.join(root, name)
        print(f'{os.path.getsize(p) / 2**20:9.2f} MB  {p}')

# In manifest ra ngay, de phong khong tai duoc file.
for slug in ('0p2', '0p3', '0p5'):
    path = pathlib.Path(OUTPUT_ROOT) / f'preflight_{slug}' / 'gate_manifest.json'
    print()
    print('=' * 24, slug, '=' * 24)
    if path.exists():
        print(json.dumps(json.loads(path.read_text()), indent=2))
    else:
        print('(khong co - stage nay chua chay)')

try:
    from IPython.display import FileLink, display
    print()
    print('Bam link duoi day de tai zip (chi dung khi chay interactive):')
    display(FileLink('causal_forest_output.zip'))
except Exception as exc:
    print('Khong tao duoc FileLink:', exc)
# Out:
# /kaggle/working/causal_forest_output.zip  30.9 MB
#
#      9.60 MB  /kaggle/working/output/causal_forest/preflight_0p3/cate_causal_forest_kaggle_safe.npy
#      0.00 MB  /kaggle/working/output/causal_forest/preflight_0p3/gate_manifest.json
#      9.60 MB  /kaggle/working/output/causal_forest/preflight_0p3/holdout_test_yt.npz
#      0.00 MB  /kaggle/working/output/causal_forest/preflight_0p3/train.log
#      6.40 MB  /kaggle/working/output/causal_forest/preflight_0p2/cate_causal_forest_kaggle_safe.npy
#      0.00 MB  /kaggle/working/output/causal_forest/preflight_0p2/gate_manifest.json
#      6.40 MB  /kaggle/working/output/causal_forest/preflight_0p2/holdout_test_yt.npz
#      0.00 MB  /kaggle/working/output/causal_forest/preflight_0p2/train.log
#     16.00 MB  /kaggle/working/output/causal_forest/preflight_0p5/cate_causal_forest_kaggle_safe.npy
#      0.00 MB  /kaggle/working/output/causal_forest/preflight_0p5/gate_manifest.json
#     16.00 MB  /kaggle/working/output/causal_forest/preflight_0p5/holdout_test_yt.npz
#      0.00 MB  /kaggle/working/output/causal_forest/preflight_0p5/train.log
#
# ======================== 0p2 ========================
# {
#   "created_utc": "2026-08-05T16:28:42.669571+00:00",
#   "status": "passed",
#   "scope": "resource_and_artifact_integrity_gate_only",
#   "fraction": 0.2,
#   "profile": "kaggle-safe",
#   "command": [
#     "/usr/bin/python3",
#     "/kaggle/working/repo/scripts/train_causal_forest.py",
#     "--data-path",
#     "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "--frac",
#     "0.2",
#     "--profile",
#     "kaggle-safe",
#     "--output-dir",
#     "/kaggle/working/output/causal_forest/preflight_0p2",
#     "--seed",
#     "42"
#   ],
#   "data": {
#     "path": "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "sha256": "e4d7c710ca1f38e523309d0f8a0745d1b53e7392d51f20d1088b6cfeaef222ef",
#     "form": "csv"
#   },
#   "runtime": {
#     "logical_cpus": 4,
#     "physical_cpus": 2,
#     "system_ram_total_gb": 31.347740173339844,
#     "system_ram_available_start_gb": 30.296844482421875,
#     "peak_process_tree_rss_gb": 5.518215179443359,
#     "peak_process_tree_ram_fraction": 0.17603231202408678,
#     "minimum_system_available_gb": 24.93988800048828,
#     "wall_seconds": 574.9599940776825,
#     "exit_code": 0
#   },
#   "artifact_contract": {
#     "score_path": "/kaggle/working/output/causal_forest/preflight_0p2/cate_causal_forest_kaggle_safe.npy",
#     "holdout_path": "/kaggle/working/output/causal_forest/preflight_0p2/holdout_test_yt.npz",
#     "score_rows": 838776,
#     "all_finite": true,
#     "aligned": true
#   },
#   "stop_rule": {
#     "max_ram_fraction": 0.75,
#     "may_continue": true,
#     "quality_not_assessed": true
#   },
#   "limitations": [
#     "Passing this gate does not show that Causal Forest improves Qini.",
#     "GPU selection does not accelerate EconML CausalForestDML itself.",
#     "Kaggle resources and quota must be read live; they are not guaranteed."
#   ]
# }
#
# ======================== 0p3 ========================
# {
#   "created_utc": "2026-08-05T16:44:03.005745+00:00",
#   "status": "passed",
#   "scope": "resource_and_artifact_integrity_gate_only",
#   "fraction": 0.3,
#   "profile": "kaggle-safe",
#   "command": [
#     "/usr/bin/python3",
#     "/kaggle/working/repo/scripts/train_causal_forest.py",
#     "--data-path",
#     "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "--frac",
#     "0.3",
#     "--profile",
#     "kaggle-safe",
#     "--output-dir",
#     "/kaggle/working/output/causal_forest/preflight_0p3",
#     "--seed",
#     "42"
#   ],
#   "data": {
#     "path": "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "sha256": "e4d7c710ca1f38e523309d0f8a0745d1b53e7392d51f20d1088b6cfeaef222ef",
#     "form": "csv"
#   },
#   "runtime": {
#     "logical_cpus": 4,
#     "physical_cpus": 2,
#     "system_ram_total_gb": 31.347740173339844,
#     "system_ram_available_start_gb": 30.270153045654297,
#     "peak_process_tree_rss_gb": 7.879417419433594,
#     "peak_process_tree_ram_fraction": 0.25135519740382317,
#     "minimum_system_available_gb": 22.582427978515625,
#     "wall_seconds": 905.8458428382874,
#     "exit_code": 0
#   },
#   "artifact_contract": {
#     "score_path": "/kaggle/working/output/causal_forest/preflight_0p3/cate_causal_forest_kaggle_safe.npy",
#     "holdout_path": "/kaggle/working/output/causal_forest/preflight_0p3/holdout_test_yt.npz",
#     "score_rows": 1258164,
#     "all_finite": true,
#     "aligned": true
#   },
#   "stop_rule": {
#     "max_ram_fraction": 0.75,
#     "may_continue": true,
#     "quality_not_assessed": true
#   },
#   "limitations": [
#     "Passing this gate does not show that Causal Forest improves Qini.",
#     "GPU selection does not accelerate EconML CausalForestDML itself.",
#     "Kaggle resources and quota must be read live; they are not guaranteed."
#   ]
# }
#
# ======================== 0p5 ========================
# {
#   "created_utc": "2026-08-05T17:10:49.285757+00:00",
#   "status": "passed",
#   "scope": "resource_and_artifact_integrity_gate_only",
#   "fraction": 0.5,
#   "profile": "kaggle-safe",
#   "command": [
#     "/usr/bin/python3",
#     "/kaggle/working/repo/scripts/train_causal_forest.py",
#     "--data-path",
#     "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "--frac",
#     "0.5",
#     "--profile",
#     "kaggle-safe",
#     "--output-dir",
#     "/kaggle/working/output/causal_forest/preflight_0p5",
#     "--seed",
#     "42"
#   ],
#   "data": {
#     "path": "/kaggle/input/datasets/datthnh/criteo-uplift-v21/criteo-uplift-v2.1.csv",
#     "sha256": "e4d7c710ca1f38e523309d0f8a0745d1b53e7392d51f20d1088b6cfeaef222ef",
#     "form": "csv"
#   },
#   "runtime": {
#     "logical_cpus": 4,
#     "physical_cpus": 2,
#     "system_ram_total_gb": 31.347740173339844,
#     "system_ram_available_start_gb": 30.302330017089844,
#     "peak_process_tree_rss_gb": 12.72928237915039,
#     "peak_process_tree_ram_fraction": 0.4060669862887341,
#     "minimum_system_available_gb": 4.989997863769531,
#     "wall_seconds": 1591.6245481967926,
#     "exit_code": 0
#   },
#   "artifact_contract": {
#     "score_path": "/kaggle/working/output/causal_forest/preflight_0p5/cate_causal_forest_kaggle_safe.npy",
#     "holdout_path": "/kaggle/working/output/causal_forest/preflight_0p5/holdout_test_yt.npz",
#     "score_rows": 2096940,
#     "all_finite": true,
#     "aligned": true
#   },
#   "stop_rule": {
#     "max_ram_fraction": 0.75,
#     "may_continue": false,
#     "quality_not_assessed": true
#   },
#   "limitations": [
#     "Passing this gate does not show that Causal Forest improves Qini.",
#     "GPU selection does not accelerate EconML CausalForestDML itself.",
#     "Kaggle resources and quota must be read live; they are not guaranteed."
#   ]
# }
#
# Bam link duoi day de tai zip (chi dung khi chay interactive):
# /kaggle/working/repo/causal_forest_output.zip

# %% [markdown]
# ## Bước tiếp theo — chạy ở local sau khi tải về
#
# Giải nén vào `output/causal_forest/` rồi chấm điểm:
#
# ```powershell
# .venv\Scripts\python.exe scripts\evaluate_causal_forest.py `
#   --stage-dir output\causal_forest\preflight_0p5 --n-boot 500 --signal dr
# ```
#
# Với stage 20% và 30%, đổi `--stage-dir` thành `preflight_0p2` / `preflight_0p3`. Script
# tự phát hiện và sẽ in `[mode] standalone` kèm cảnh báo rằng holdout đó **không** so được
# với bảng release.
#
# ## Ba điều không được viết vào báo cáo
#
# 1. So Qini stage 20% với `0,187886` của Response — hai tập test khác nhau.
# 2. "Gate pass nghĩa là model tốt" — gate chỉ kiểm tài nguyên và toàn vẹn artifact;
#    `"quality_not_assessed": true` nằm ngay trong manifest.
# 3. "Causal Forest cho khoảng tin cậy cá nhân" — profile `kaggle-safe` đặt
#    `inference=False`, không gọi `effect_interval()` được.
